# %% [markdown]
# <a href="https://colab.research.google.com/github/xeqoir/Finance/blob/main/FIMA/FamaFrenchThreeFactorsMonthly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
file = pd.read_csv("https://raw.githubusercontent.com/xeqoir/Finance/refs/heads/main/FamaFrenchThreeFactorsMonthly.csv")
file = file.apply(pd.to_numeric, errors='coerce').dropna()
file
# Out:
#           Date  Mkt-RF    SMB    HML    RF
# 0     192607.0    2.96  -2.56  -2.43  0.22
# 1     192608.0    2.64  -1.17   3.82  0.25
# 2     192609.0    0.36  -1.40   0.13  0.23
# 3     192610.0   -3.24  -0.09   0.70  0.32
# 4     192611.0    2.53  -0.10  -0.51  0.31
# ...        ...     ...    ...    ...   ...
# 1251    2017.0   21.51  -4.97 -13.51  0.80
# 1252    2018.0   -6.95  -3.21  -9.73  1.83
# 1253    2019.0   28.28  -6.10 -10.34  2.15
# 1254    2020.0   23.66  13.17 -46.57  0.45
# 1255    2021.0   23.56  -3.92  25.57  0.04
#
# [1250 rows x 5 columns]

# %%
# Separate factors and dependent variable
X_3factor = file[['Mkt-RF', 'SMB', 'HML']]  # 3-factor model inputs
y = file['Mkt-RF']  # Dependent variable (e.g., asset return - risk-free rate)
X_3factor = sm.add_constant(X_3factor)  # Add intercept

# %%
model_3factor = sm.OLS(y, X_3factor).fit()
print("Fama-French 3-Factor Model Results:")
print(model_3factor.summary())
# Out:
# Fama-French 3-Factor Model Results:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Mkt-RF   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.774e+33
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        03:38:34   Log-Likelihood:                 39728.
# No. Observations:                1250   AIC:                        -7.945e+04
# Df Residuals:                    1246   BIC:                        -7.943e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.752e-15    1.1e-16     15.957      0.000    1.54e-15    1.97e-15
# ...
